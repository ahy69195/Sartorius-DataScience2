# %%
# To add packages to julia run these lines only once on your machine.


# import Pkg;
# Pkg.add("Images")
# Pkg.add("ImageView")
# Pkg.add("CSV")
# Pkg.add("DataFrames")

# %%
using Images, ImageView, CSV, DataFrames

# %% [markdown]
# ## The dimesions of the images we have

# %%
pixels=704;
lines=520;

# %% [markdown]
# ## We're going to load the CSV 'train' file here

# %%
train_data = DataFrame(CSV.File("dataset\\train.csv"));

# %% [markdown]
# ## Here we need to go through the CSV file line by line and extract these things:
# - Name of the '.png' file
# - Annotations
# - Type of the cell

# %%
td = select(train_data,1,2,5);

# %% [markdown]
# This function takes a black image and the annotations, and fills the designated pixels in white

# %%
function fill_white(img::Matrix{Float64}, annot::String) 
    # Splitting the string by space character
    mask_array = split(annot,' ');
    # Changint the type of the elements to Int32
    mask_array = parse.(Int32,mask_array)
    # The easiest way is to flatten image, this way, our flattened image looks
    # very similar to the annotation and we can easily change the desired pixel
    # values to white
    flattened_img = reshape(img,1,pixels*lines)
    
    # Starting to fill the pixels to white
    for i in 1:2:length(mask_array)
        # from the starting pixel number + all the consequent pixels
        # mask_array[i] is the pixel umber
        # mask_array[i+1] is the length or the number of following pixels
        for j in mask_array[i]:mask_array[i]+mask_array[i+1]-1
            # Make it white
            try
                flattened_img[1,j]=1
            catch e
              bt = backtrace()
              msg = sprint(showerror, e, bt)
              println(msg)
            end
            
        end
    end
    # The weird thing about Julia is that they count pixels in an image column after column
    # from left to right, instead of row after row from top to bottom for this reason
    # the ' at the end of the following code is needed to Transposes the image so that the output
    # will be the same dimension as the original
    img = reshape(flattened_img,pixels,lines)'
    return img
end
# Out:
# fill_white (generic function with 1 method)

# %%
prev_file_name=""
ind=1
for row in 1:size(td)[1]
    file_name = td[row,"id"]
    if prev_file_name != file_name
        prev_file_name = file_name
        ind = 1
        println("processing image:",file_name)
    else
        ind+=1
    end
    annot = td[row,"annotation"]
    cell_type = td[row,"cell_type"]
    # create an image of size width=pixels, height=lines and fill all pixels black
    img = zeros(lines,pixels);
    # Call fill_white function to fill annotated pixels in white
    img = fill_white(img,annot)
    # Very self-explanatory
    save("dataset\\train\\"*file_name*"\\"*file_name*"_"*string(ind)*".png",img)
end
# Out:
# processing image:0030fd0e6378
# processing image:0140b3c8f445
# processing image:01ae5a43a2ab
# processing image:026b3c2c4b32
# processing image:029e5b3b89c7
# processing image:0323e81d23d9
# processing image:03b27b381a5f
# processing image:042c17cd9143
# processing image:042dc0e561a4
# processing image:04928f0866b0
# processing image:049f02e0f764
# processing image:04cd81dfb245
# processing image:053d61766edb
# processing image:05c61f0f46b7
# processing image:061b49d7dbbb
# processing image:06c5740c8b18
# processing image:0728b8f39241
# processing image:07e9ba109e34
# processing image:083b178bb184
# processing image:085eb8fec206
# processing image:08f52aa2add3
# processing image:097d60b2cf71
# processing image:0a6ecc5fe78a
# processing image:0ba181d412da
# processing image:0c5938ac5e3c
# processing image:0c90b86742b2
# processing image:0cfdeeb0dded
# processing image:0df9d6419078
# processing image:0e1e2b68fa58
# processing image:0e9b40b10de8
# processing image:0ea6df67cc77
# processing image:0eb1d03df587
# processing image:0eca9ecf4987
# processing image:0f08d640930b
# processing image:0f2a46026693
# processing image:0f7d009bc5d3
# processing image:100681b6cc7a
# processing image:115fad550598
# processing image:11c136be56b7
# processing image:11c2e4fcac6d
# processing image:1242e4ec6ef3
# processing image:129f894abe35
# processing image:13325f865bb0
# processing image:1395c3f12b7c
# processing image:144a7a69f67d
# processing image:14dbd973a7cd
# processing image:15283b194621
# processing image:152bcf26456b
# processing image:15aeb12e7a83
# processing image:16e538bbe8c5
# processing image:172334437c88
# processing image:174793807517
# processing image:17754cb5b287
# processing image:17d738f88487
# processing image:182c3da676bd
# processing image:1874b96fd317
# processing image:18d5d665a6af
# processing image:194f7e69779b
# processing image:1974fbb27dcf
# processing image:198593a55b7a
# processing image:1b539d8a8897
# processing image:1bf60e3be6ce
# processing image:1c10ee85de67
# processing image:1c16d5cb1f30
# processing image:1c4f14cce8ee
# processing image:1c60d7a7695d
# processing image:1cc3b45e0399
# processing image:1ce663c98a16
# processing image:1d2396667910
# processing image:1d2ca29fef3e
# processing image:1d618b80769f
# processing image:1d8ea1f865e0
# processing image:1d9cf05975eb
# processing image:1de9612cb6e1
# processing image:1e55de6c2a34
# processing image:1e60fc475228
# processing image:1e7ac54a9422
# processing image:1ea4e44e5497
# processing image:1ef6aaa62132
# processing image:1f81ad0e1fb6
# processing image:1f8ff922773c
# processing image:2025512a5956
# processing image:20598fa21a3d
# processing image:2099abcae734
# processing image:20dc08f66f3f
# processing image:213f5c108080
# processing image:21b1ae35bd39
# processing image:22e0c43da285
# processing image:232c47d31333
# processing image:235f6d2095c9
# processing image:2384e7378d16
# processing image:23e6d1174f47
# processing image:242de8187041
# processing image:24a07145b24d
# processing image:24ed4b9f417d
# processing image:25559c20c6f3
# processing image:25c4b29d2189
# processing image:25fc36476862
# processing image:25fd50629a5c
# processing image:26d58ec4353a
# processing image:26efe388938c
# processing image:279107cc7fe4
# processing image:27f4ea4dd04f
# processing image:286415b46ebb
# processing image:296926b5656b
# processing image:29dfe87f3a44
# processing image:29efe1120825
# processing image:2be2ec84ac11
# processing image:2c2cb870da85
# processing image:2c7b7d0a1573
# processing image:2cab2cb161a4
# processing image:2d8810967b36
# processing image:2d9fd17da790
# processing image:2dbfcf0fc496
# processing image:2dc940ff1a71
# processing image:2e8a61b4f6b5
# processing image:2f1b9aea78d7
# processing image:303e22f9ccd3
# processing image:309be9da24d7
# processing image:315b21b955c6
# processing image:31e4fa0a83f4
# processing image:34b6c5235ab4
# processing image:34bd8ce0c802
# processing image:34e41956f993
# processing image:358c8b7a8204
# processing image:35fc12883459
# processing image:3625dabdf452
# processing image:364feb876754
# processing image:36855e37531a
# processing image:36e480c65aed
# processing image:37dd4dd6e76e
# processing image:3912a0bede5b
# processing image:393c8540c6fa
# processing image:3ac59a41a300
# processing image:3b3991c64f38
# processing image:3b56cced208e
# processing image:3b70c0fef171
# processing image:3bcc8ba1dc17
# processing image:3be8cce336d0
# processing image:3c270e8e347a
# processing image:3cb9d7266ea1
# processing image:3dd0e512b579
# processing image:3e0a07a7dcfc
# processing image:3f14453053d4
# processing image:3f29e529f210
# processing image:3f6e72d6647d
# processing image:40d3650f4985
# processing image:40db2225676e
# processing image:40fddf5f9595
# processing image:411a7b067dcc
# processing image:418853314d5b
# processing image:41a1f09b4f4e
# processing image:41c57fe26957
# processing image:42d8ecbc95a1
# processing image:4318b7f15a71
# processing image:4378ec854810
# processing image:43d929bd6429
# processing image:4425efbbacfc
# processing image:446cf8ba65e5
# processing image:44752904b4d5
# processing image:44a154410273
# processing image:44c353126f35
# processing image:44e1c6996c16
# processing image:4551bb9de3fa
# processing image:45a1f06614f0
# processing image:45b966b60d4b
# processing image:4698edfd5878
# processing image:46b08b7eee99
# processing image:478a2c53f075
# processing image:47c3b766d82e
# processing image:47fb5fcff2de
# processing image:4810ddb4229c
# processing image:48383b66ebd5
# processing image:48a750fc02a2
# processing image:4984db4ec8f3
# processing image:499a225c835d
# processing image:49d4a04f398c
# processing image:4b21aa9b6c84
# processing image:4b6ba2567ab0
# processing image:4b701c599d33
# processing image:4b8dc9c901a6
# processing image:4bdf75f87261
# processing image:4c744a767648
# processing image:4c98ec6b42aa
# processing image:4cd85ba270d0
# processing image:4cef27c8f779
# processing image:4cf637b37b8b
# processing image:4cf8f24c2b17
# processing image:4d52c84bfe79
# processing image:4de92f67c5b8
# processing image:4e115eccc68c
# processing image:4e360cb49ae4
# processing image:4e99b18bf20f
# processing image:4ec5008ab318
# processing image:4f9f9b90a3c1
# processing image:508d39dcc9ef
# processing image:517648559341
# processing image:51c920fcd542
# processing image:5286d9ca0f92
# processing image:529f53145d75
# processing image:52a2e248d75b
# processing image:52e810d1f2f0
# processing image:52ea449bc02d
# processing image:52f65c9194c0
# processing image:539f24ebc61d
# processing image:541ab846bcb0
# processing image:541d7fd43b66
# processing image:549d34aaf226
# processing image:5507c81bdcb6
# processing image:551738f39e65
# processing image:559904fcd4a2
# processing image:563435d64260
# processing image:568a4f5d0593
# processing image:56b8cad4f8e7
# processing image:56e473c7c793
# processing image:56e62b1803c4
# processing image:576c680c66c7
# processing image:57bc63239549
# processing image:5863bf795692
# processing image:588931a27780
# processing image:58b543a236c8
# processing image:59833fe3d0f9
# processing image:59eecb1504fa
# processing image:5a05cc33a43d
# processing image:5a880b2b403e
# processing image:5b0469b7bd04
# processing image:5b8e5ee1ec61
# processing image:5bbf4c20aad2
# processing image:5bc68ac7426e
# processing image:5c252798d269
# processing image:5c4f72978ff6
# processing image:5c84424f601c
# processing image:5d066f4c3eef
# processing image:5d57448ab949
# processing image:5df720a4fad6
# processing image:5e04f48d34e3
# processing image:5e9130834984
# processing image:5eb16b1cf176
# processing image:6064a286cbf3
# processing image:606831bd2dd2
# processing image:60a7ba541038
# processing image:619f91a5c197
# processing image:6244275a0951
# processing image:624d50b5bfd1
# processing image:625c65b50aa1
# processing image:626f74f1e5f6
# processing image:630bac646b5a
# processing image:63dbe67dbab4
# processing image:642d9cbe7f15
# processing image:66a902c45432
# processing image:6725005514cc
# processing image:680c18cb5fea
# processing image:68141f4dacd7
# processing image:6867e380fe3c
# processing image:68780361eded
# processing image:6955df3e6c27
# processing image:6955f473e6f5
# processing image:699757ca44a7
# processing image:6a119b8773c6
# processing image:6a71d6253a42
# processing image:6b165d790e33
# processing image:6b2f2fab222f
# processing image:6b6f2ee6467a
# processing image:6d9c64988769
# processing image:6e8c9b707724
# processing image:6f90a53cf326
# processing image:704f269a8415
# processing image:70a94f058409
# processing image:71d6e508abdc
# processing image:724097951299
# processing image:729cc4463650
# processing image:72d38d5c6be1
# processing image:73c45accba88
# processing image:73df2962444f
# processing image:741edb5bb8f5
# processing image:74a506f1d7e8
# processing image:74bb773bab01
# processing image:74eba54b3ae5
# processing image:7570dd2d34bb
# processing image:757253a07cd3
# processing image:75a735d52727
# processing image:75bcf651967e
# processing image:762d6b2ee6da
# processing image:76ad9ac01e2d
# processing image:76f6eb941d56
# processing image:77f5123c8582
# processing image:78440cb4b47d
# processing image:7898358115a7
# processing image:795651f7b04a
# processing image:798c6a9ca18c
# processing image:79b77c62a9f3
# processing image:79c353271ce9
# processing image:79d271434d64
# processing image:7ab1bc1c47f1
# processing image:7ad870da5a63
# processing image:7b27ca965a93
# processing image:7b2818817d0d
# processing image:7b67cd233fcd
# processing image:7c118cb496f7
# processing image:7ca93f81e669
# processing image:7cc6beb96b81
# processing image:7d13efbfce6d
# processing image:7d3174bf78a1
# processing image:7d357c4f7438
# processing image:7d45ca9a700d
# processing image:7d59ab1d21a2
# processing image:7e30fccf0a91
# processing image:7f21996da2e6
# processing image:7f27bcdc5e5d
# processing image:8050704a02eb
# processing image:8122040d9ecd
# processing image:815de003cb5b
# processing image:82a96cda2a44
# processing image:82c638427f2f
# processing image:836e5872684a
# processing image:84318d167a6c
# processing image:844ca72ea4c0
# processing image:8501cf5525d4
# processing image:853026457c51
# processing image:8541146e15d9
# processing image:856cbd30d034
# processing image:85cbc2e3905e
# processing image:8650b0110eb6
# processing image:86be12afefb6
# processing image:874f3f4e1e6b
# processing image:875775b0a33f
# processing image:878db7a5ab51
# processing image:87a052b69db0
# processing image:87aabe7ab3a5
# processing image:87e2b185e074
# processing image:88203fd2557d
# processing image:8917c2f4445e
# processing image:8966df7b976b
# processing image:89dceefff181
# processing image:8a60bdad42ff
# processing image:8a754409504b
# processing image:8ae77a7c490c
# processing image:8b6d3ad0fb2d
# processing image:8bcc2ef2e81e
# processing image:8bd09ff70b13
# processing image:8c90ed01dfa0
# processing image:8cc78aff9cc6
# processing image:8d0f8970d171
# processing image:8e2b69117149
# processing image:8e7199072220
# processing image:8f276651b26c
# processing image:8f6d3deadc55
# processing image:90016c8865d3
# processing image:903d94c69354
# processing image:90a3e24b62b0
# processing image:919748e5c24c
# processing image:91b6e6e0d84d
# processing image:91c06d4f10df
# processing image:930015180836
# processing image:930699898b1c
# processing image:9379e29d719d
# processing image:93ba6784a818
# processing image:93ce48e5227c
# processing image:94198e5b42a4
# processing image:957d8951b270
# processing image:95ac5f4182fa
# processing image:95de75855f80
# processing image:95e46e2b296f
# processing image:960479eea44e
# processing image:96304c6e06eb
# processing image:96b7471ba87d
# processing image:97b66f10b9f5
# processing image:98fd9ed43654
# processing image:996aad57d020
# processing image:9a065ab4fae7
# processing image:9ae06a9d5011
# processing image:9ae46e01286c
# processing image:9b362a5983ae
# processing image:9b6b19ec0736
# processing image:9bc9775ee371
# processing image:9c0f16816345
# processing image:9c4661d1509c
# processing image:9c7e1ff93090
# processing image:9cfd6ebebc94
# processing image:9d23373b7bf8
# processing image:9e2bc2d20e43
# processing image:9e8da786a80f
# processing image:9f1c2cfc936f
# processing image:a049e2a265cf
# processing image:a0ee7192f838
# processing image:a136a96476b3
# processing image:a162768bcf04
# processing image:a1aab9d6b6b2
# processing image:a1ff383ad7ff
# processing image:a28407ce196e
# processing image:a55a105360b8
# processing image:a55cec7ee7a1
# processing image:a686c4329d91
# processing image:a71bd3fbf8f1
# processing image:a75cdb426a8e
# processing image:a76fe4d00355
# processing image:a7b1db2a42fc
# processing image:a85fbc42127a
# processing image:a87eed6346d5
# processing image:a96cf05207fc
# processing image:a97d5689d4c2
# processing image:a9cf3efd023a
# processing image:a9fc5e872671
# processing image:aa2e2c09a57b
# processing image:ab00526e7901
# processing image:abd3833b5ac1
# processing image:ac12dab88a3d
# processing image:ac877991fa24
# processing image:aca02da8ef58
# processing image:ad12c1357f63
# processing image:ad30ecfc1682
# processing image:ad41b4c2bf73
# processing image:adbaf2416db2
# processing image:adfd16bee70c
# processing image:ae1509f591ce
# processing image:ae3baa051773
# processing image:ae509c50607a
# processing image:af47d104aa7e
# processing image:af54fcc34740
# processing image:af6ae867fe6e
# processing image:af890034c1b6
# processing image:afbcea22fc2a
# processing image:aff8fb4fc364
# processing image:b03de5cbebb2
# processing image:b0a5b4340364
# processing image:b0c3bd326249
# processing image:b1687f869c0a
# processing image:b1cc1e8aeecd
# processing image:b208a1b645a1
# processing image:b29b7cb8c7e4
# processing image:b2a7f3d06a50
# processing image:b307d66eb656
# processing image:b3990528329c
# processing image:b4713c32ddbb
# processing image:b50a98297c83
# processing image:b53a3bfd3bd0
# processing image:b5afaf901478
# processing image:b66e76eb1f3f
# processing image:b684e5076578
# processing image:b81db12284ff
# processing image:b861811eaff6
# processing image:b867d9f2d373
# processing image:b8759ed1bf33
# processing image:b89f9cca5384
# processing image:b9056ac30b4b
# processing image:ba9dd157fb69
# processing image:bb3520da4cce
# processing image:bc0b9c1ff4dc
# processing image:bcf94f6bc975
# processing image:be85d2d45959
# processing image:bebd2d51a0d0
# processing image:bee779e5729d
# processing image:bf44c49ba659
# processing image:bfb878cd992e
# processing image:c019b279bed8
# processing image:c0b82bc0600d
# processing image:c0dff5f1af2f
# processing image:c17eac09ff70
# processing image:c1a8710f13a5
# processing image:c1f3e3b31108
# processing image:c25db38e918e
# processing image:c362cb822d6b
# processing image:c3b32460bcba
# processing image:c4121689002f
# processing image:c48e1469ac98
# processing image:c4dc7ddff8ec
# processing image:c5be3066e673
# processing image:c67dd29ad915
# processing image:c6981f294012
# processing image:c6a9863504da
# processing image:c7b6b79d6276
# processing image:c7cb35a80237
# processing image:c8522b0f2063
# processing image:c8607b0581bf
# processing image:c895cf319088
# processing image:c97cc03675c7
# processing image:c98b451417f7
# processing image:c9c3465d8941
# processing image:c9d4c2430d92
# processing image:c9e81c79ca72
# processing image:ca167f336091
# processing image:ca5df17f6717
# processing image:caa06f9a4057
# processing image:cb07e23f138a
# processing image:cc40345857dd
# processing image:cc8526acd4fe
# processing image:cca71932b689
# processing image:ccf6e108fb22
# processing image:ce453794c74d
# processing image:ce5d0de993bd
# processing image:cfe901b30e8d
# processing image:d0747a9ed004
# processing image:d08ec01979f3
# processing image:d09291445961
# processing image:d132b291f6cc
# processing image:d14e4fe1fef1
# processing image:d164e96bb7a9
# processing image:d1d1ca1bfb8a
# processing image:d1db733a1edd
# processing image:d21676dcf3a2
# processing image:d248e894403c
# processing image:d28e67c1ad17
# processing image:d3bd573a3dc4
# processing image:d3d272e75cdb
# processing image:d575336b8f7a
# processing image:d5a2e9d0e602
# processing image:d5c06777eee7
# processing image:d62093ffe38d
# processing image:d75d5d14fdcb
# processing image:d7aa803f5b5f
# processing image:d7f8c3d595e9
# processing image:d81712416572
# processing image:d8353ec73bdf
# processing image:d8fc6dd956f8
# processing image:d914af4080bb
# processing image:d96878ba3ab6
# processing image:d97922f1d446
# processing image:dac9a173832d
# processing image:db5260527117
# processing image:db5ad777646f
# processing image:db8bc8f09776
# processing image:dc18ef9b49f5
# processing image:dc6beb2a50a9
# processing image:dd8bcbe5094b
# processing image:de35454a3346
# processing image:de504eaa5349
# processing image:de72de636483
# processing image:dead8d6e0ea8
# processing image:df54ca550ecd
# processing image:e013dbefe5c4
# processing image:e0ad75ccddab
# processing image:e103a3e85a46
# processing image:e1140f76536a
# processing image:e117dfd2ae8b
# processing image:e1e10dd96535
# processing image:e201f565a7d8
# processing image:e29015d36459
# processing image:e2fc3f4577e2
# processing image:e33d521aa9de
# processing image:e33da393df22
# processing image:e41558ca4bae
# processing image:e460317d8ca9
# processing image:e4632744011e
# processing image:e4f28f1ea4ee
# processing image:e52789a0a1f5
# processing image:e57626198284
# processing image:e5937076f423
# processing image:e6a4f5e6d65d
# processing image:e6aff490e966
# processing image:e748ac1c469b
# processing image:e767fd549540
# processing image:e76b2a9735f8
# processing image:e856f45ec69e
# processing image:e8ae919aa92e
# processing image:e92c56871769
# processing image:e96b5ddfef20
# processing image:e97e043aa093
# processing image:e9edcd9483e4
# processing image:ea362f1a9844
# processing image:eac668a9ea37
# processing image:eb9c10862d4e
# processing image:ebaa75979438
# processing image:ebffbf1cfe00
# processing image:ec1d0a62b17c
# processing image:ec5b56d79061
# processing image:ececc1fe265d
# processing image:ed0fcca57fe8
# processing image:edbb15612a94
# processing image:ee6d4d0a17b6
# processing image:ee6ddcdc19ce
# processing image:eec79772cb99
# processing image:ef866d97431e
# processing image:efdf3822846c
# processing image:efec0322798a
# processing image:f00798e9b1eb
# processing image:f0111570ede9
# processing image:f0e54d645fe5
# processing image:f17f964687b3
# processing image:f1fafe9e540f
# processing image:f25af915d4e8
# processing image:f2d0421bcc7b
# processing image:f2e0ce316b7e
# processing image:f357b9dabe13
# processing image:f3b46561d429
# processing image:f40567565202
# processing image:f41cd55e692d
# processing image:f555eba5ddc5
# processing image:f64c628ef828
# processing image:f653c5eec0f8
# processing image:f6abc09eb12f
# processing image:f6e7e998a190
# processing image:f717a5f6d473
# processing image:f7343d843bbd
# processing image:f7450aa3df7f
# processing image:f76d1d2d5405
# processing image:f843561f9e18
# processing image:f8902ee8890c
# processing image:f982188d7249
# processing image:faa16dd8abd3
# processing image:fac5fa0dd448
# processing image:fbb4fbe7100d
# processing image:fd98d82784a1
# processing image:fe33dfcf4ebd
# processing image:fe3e30f849f4
# processing image:ffc2ead3e8cc
# processing image:ffdb3cc02eef
